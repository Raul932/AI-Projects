# %%
from tensorflow.keras.datasets import mnist

# 1) Load the data: x’s are 28×28 images, y’s are integer labels 0–9
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# 2) Normalize pixels from [0–255] → [0–1]
x_train = x_train.astype('float32') / 255.0
x_test  = x_test.astype('float32') / 255.0

# 3) Flatten each 28×28 image into a 784‐vector
x_train = x_train.reshape(-1, 28 * 28)
x_test  = x_test.reshape(-1, 28 * 28)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.datasets import mnist
#       3 # 1) Load the data: x’s are 28×28 images, y’s are integer labels 0–9
#       4 (x_train, y_train), (x_test, y_test) = mnist.load_data()
#
# ModuleNotFoundError: No module named 'tensorflow'
